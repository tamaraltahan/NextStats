# %%
from dataAggregator import gameStats
import json
#import sys

# %%
#id = sys.argv[1]
#me:
#id = 1986753

#mirza:
#id = 101664373

#osama:
#id = 110915293

#kelley:
id = 148239542

# %%
Data = gameStats(id)

# %%
dat = Data.getData()

# %%
Data.getPlayerStats()
# Out:
# {'meanWins': 50.64410958904109,
#  'meanTotal': 3847.4520547945203,
#  'stdWins': 2.8027133854814292,
#  'stdTotal': 2787.855408538852}

# %%
Data.outlierData
# Out:
# {'outlierWinsPositive': {95415806: {'win': 220,
#    'lose': 170,
#    'total': 390,
#    'winPercent': 56.41},
#   1200689250: {'win': 265, 'lose': 197, 'total': 462, 'winPercent': 57.36}},
#  'outlierTotalsPositive': {2353220: {'win': 7690,
#    'lose': 7675,
#    'total': 15365,
#    'winPercent': 50.05},
#   42338190: {'win': 4371, 'lose': 4295, 'total': 8666, 'winPercent': 50.44},
#   10725348: {'win': 4214, 'lose': 4079, 'total': 8293, 'winPercent': 50.81},
#   149671039: {'win': 5004, 'lose': 4996, 'total': 10000, 'winPercent': 50.04},
#   374025357: {'win': 4350, 'lose': 4140, 'total': 8490, 'winPercent': 51.24}},
#  'outliersWinsNegative': {67913486: {'win': 1,
#    'lose': 2,
#    'total': 3,
#    'winPercent': 33.33},
#   177966150: {'win': 35, 'lose': 41, 'total': 76, 'winPercent': 46.05}},
#  'outliersTotalNegative': {},
#  'highWinLowGames': {},
#  'lowWinLowGames': {},
#  'winPercentThreshold': 4.204070078222144,
#  'totalGamesThreshold': 4181.783112808278}

# %%
Data.getData()
# Out:
# '{"playerData": {"64760375": {"win": 3552, "lose": 3500, "total": 7052, "winPercent": 50.37}, "106021406": {"win": 2269, "lose": 2238, "total": 4507, "winPercent": 50.34}, "86956724": {"win": 3022, "lose": 3165, "total": 6187, "winPercent": 48.84}, "84460388": {"win": 2037, "lose": 2100, "total": 4137, "winPercent": 49.24}, "111760652": {"win": 4007, "lose": 4014, "total": 8021, "winPercent": 49.96}, "101664373": {"win": 3639, "lose": 3623, "total": 7262, "winPercent": 50.11}, "1986753": {"win": 3364, "lose": 3378, "total": 6742, "winPercent": 49.9}, "294155488": {"win": 1517, "lose": 1520, "total": 3037, "winPercent": 49.95}, "15298726": {"win": 2465, "lose": 2364, "total": 4829, "winPercent": 51.05}, "33195456": {"win": 2302, "lose": 2371, "total": 4673, "winPercent": 49.26}, "43829408": {"win": 1226, "lose": 1284, "total": 2510, "winPercent": 48.84}, "71685953": {"win": 1658, "lose": 1540, "total": 3198, "winPercent": 51.84}, "489922976": {"win": 514, "lose": 553, "total": 1067, "
# ...

# %%
type(Data.getData())
# Out:
# str

# %%
myJson = json.dumps(Data.getData())

# %%
myJson
# Out:
# '"{\\"playerData\\": {\\"64760375\\": {\\"win\\": 3552, \\"lose\\": 3500, \\"total\\": 7052, \\"winPercent\\": 50.37}, \\"106021406\\": {\\"win\\": 2269, \\"lose\\": 2238, \\"total\\": 4507, \\"winPercent\\": 50.34}, \\"86956724\\": {\\"win\\": 3022, \\"lose\\": 3165, \\"total\\": 6187, \\"winPercent\\": 48.84}, \\"84460388\\": {\\"win\\": 2037, \\"lose\\": 2100, \\"total\\": 4137, \\"winPercent\\": 49.24}, \\"111760652\\": {\\"win\\": 4007, \\"lose\\": 4014, \\"total\\": 8021, \\"winPercent\\": 49.96}, \\"101664373\\": {\\"win\\": 3639, \\"lose\\": 3623, \\"total\\": 7262, \\"winPercent\\": 50.11}, \\"1986753\\": {\\"win\\": 3364, \\"lose\\": 3378, \\"total\\": 6742, \\"winPercent\\": 49.9}, \\"294155488\\": {\\"win\\": 1517, \\"lose\\": 1520, \\"total\\": 3037, \\"winPercent\\": 49.95}, \\"15298726\\": {\\"win\\": 2465, \\"lose\\": 2364, \\"total\\": 4829, \\"winPercent\\": 51.05}, \\"33195456\\": {\\"win\\": 2302, \\"lose\\": 2371, \\"total\\": 4673, \\"winPercent\\": 49.26}, \\"4
# ...
